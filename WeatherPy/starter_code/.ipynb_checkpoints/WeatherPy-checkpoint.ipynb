# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f2e7be3fbf6a6ca5ee22f83c7998246c"
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | upernavik
# Processing Record 3 of Set 1 | nago
# Processing Record 4 of Set 1 | palu
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | narrabri
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | harpanahalli
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | kazachinskoye
# Processing Record 11 of Set 1 | la romana
# Processing Record 12 of Set 1 | bengkulu
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | vardo
# Processing Record 15 of Set 1 | kindu
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | talnakh
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | geraldton
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | mahibadhoo
# Processing Record 27 of Set 1 | sidi ali
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | farah
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | kangaatsiaq
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | palotina
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | bambous virieux
# Processing Record 39 of Set 1 | poum
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | ubatuba
# Processing Record 42 of Set 1 | beloha
# Processing Record 43 of Set 1 | senador jose porfirio
# Processing Record 44 of Set 1 | kamina
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | panjab
# Processing Record 48 of Set 1 | sao filipe
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | abay
# Processing Record 0 of Set 2 | bilibino
# Processing Record 1 of Set 2 | manzanillo
# Processing Record 2 of Set 2 | kloulklubed
# Processing Record 3 of Set 2 | sobolevo
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | saint george
# Processing Record 7 of Set 2 | lagoa
# Processing Record 8 of Set 2 | andijon
# Processing Record 9 of Set 2 | sinop
# Processing Record 10 of Set 2 | bangangte
# Processing Record 11 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 2 | richards bay
# Processing Record 13 of Set 2 | isangel
# Processing Record 14 of Set 2 | mao
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | cumpas
# Processing Record 17 of Set 2 | havoysund
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | manokwari
# Processing Record 21 of Set 2 | mainit
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | yulara
# Processing Record 24 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 2 | hambantota
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | paamiut
# Processing Record 28 of Set 2 | kirensk
# Processing Record 29 of Set 2 | kushmurun
# Processing Record 30 of Set 2 | russellville
# Processing Record 31 of Set 2 | baykit
# Processing Record 32 of Set 2 | kishorganj
# Processing Record 33 of Set 2 | makakilo city
# Processing Record 34 of Set 2 | port-cartier
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | puerto montt
# Processing Record 38 of Set 2 | port hardy
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | tomatlan
# Processing Record 42 of Set 2 | saint-joseph
# Processing Record 43 of Set 2 | pisco
# Processing Record 44 of Set 2 | sayabec
# City not found. Skipping...
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | sibut
# Processing Record 47 of Set 2 | talbahat
# Processing Record 48 of Set 2 | sechura
# Processing Record 49 of Set 2 | nemuro
# Processing Record 0 of Set 3 | longyearbyen
# Processing Record 1 of Set 3 | ushuaia
# Processing Record 2 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 3 of Set 3 | okhotsk
# Processing Record 4 of Set 3 | evensk
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 3 | xiongzhou
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | rennes
# Processing Record 10 of Set 3 | saurimo
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | kankan
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | gambela
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 3 | caraballeda
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | tyazhinskiy
# Processing Record 24 of Set 3 | cabedelo
# Processing Record 25 of Set 3 | namatanai
# Processing Record 26 of Set 3 | qafsah
# City not found. Skipping...
# Processing Record 27 of Set 3 | sitka
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | faya
# Processing Record 30 of Set 3 | komsomolskiy
# Processing Record 31 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | mnogovershinnyy
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | santa cruz de la palma
# Processing Record 35 of Set 3 | clyde river
# Processing Record 36 of Set 3 | tari
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | denpasar
# Processing Record 39 of Set 3 | puerto leguizamo
# Processing Record 40 of Set 3 | jiuquan
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | port lincoln
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | yambio
# Processing Record 46 of Set 3 | calbuco
# Processing Record 47 of Set 3 | la ronge
# Processing Record 48 of Set 3 | vila velha
# Processing Record 49 of Set 3 | antofagasta
# Processing Record 0 of Set 4 | fredonia
# Processing Record 1 of Set 4 | kholm
# Processing Record 2 of Set 4 | sarkand
# Processing Record 3 of Set 4 | marzuq
# Processing Record 4 of Set 4 | sao jose da coroa grande
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | atikokan
# Processing Record 7 of Set 4 | merauke
# Processing Record 8 of Set 4 | provideniya
# Processing Record 9 of Set 4 | mantua
# Processing Record 10 of Set 4 | ayr
# Processing Record 11 of Set 4 | chachapoyas
# Processing Record 12 of Set 4 | winsum
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | katherine
# Processing Record 15 of Set 4 | la paz
# Processing Record 16 of Set 4 | oktyabrskiy
# Processing Record 17 of Set 4 | bethlehem
# Processing Record 18 of Set 4 | ulaanbaatar
# Processing Record 19 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 4 | dubenskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | college
# Processing Record 23 of Set 4 | branford
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | ilheus
# Processing Record 26 of Set 4 | iqaluit
# Processing Record 27 of Set 4 | hurricane
# Processing Record 28 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 4 | sorong
# Processing Record 30 of Set 4 | ahipara
# Processing Record 31 of Set 4 | sur
# Processing Record 32 of Set 4 | ercis
# Processing Record 33 of Set 4 | awjilah
# Processing Record 34 of Set 4 | iesolo
# Processing Record 35 of Set 4 | konosha
# Processing Record 36 of Set 4 | grand gaube
# Processing Record 37 of Set 4 | victoria
# Processing Record 38 of Set 4 | bud
# Processing Record 39 of Set 4 | ewa beach
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | umm lajj
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 4 | alta floresta
# Processing Record 44 of Set 4 | constitucion
# Processing Record 45 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | saint-philippe
# Processing Record 49 of Set 4 | oranjestad
# Processing Record 0 of Set 5 | namibe
# Processing Record 1 of Set 5 | tselinnoye
# Processing Record 2 of Set 5 | strezhevoy
# Processing Record 3 of Set 5 | alexandria
# Processing Record 4 of Set 5 | russkaya polyana
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | ponta do sol
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | rosetta
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | cap malheureux
# Processing Record 11 of Set 5 | wundanyi
# Processing Record 12 of Set 5 | high level
# Processing Record 13 of Set 5 | kavaratti
# Processing Record 14 of Set 5 | mizdah
# Processing Record 15 of Set 5 | zhengjiatun
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | vao
# Processing Record 18 of Set 5 | port blair
# Processing Record 19 of Set 5 | koumac
# Processing Record 20 of Set 5 | thunder bay
# Processing Record 21 of Set 5 | japura
# Processing Record 22 of Set 5 | popova
# Processing Record 23 of Set 5 | new norfolk
# Processing Record 24 of Set 5 | ostrovnoy
# Processing Record 25 of Set 5 | traverse city
# Processing Record 26 of Set 5 | fort nelson
# Processing Record 27 of Set 5 | roswell
# Processing Record 28 of Set 5 | chumikan
# Processing Record 29 of Set 5 | norman wells
# Processing Record 30 of Set 5 | palmerston
# Processing Record 31 of Set 5 | portland
# Processing Record 32 of Set 5 | talara
# Processing Record 33 of Set 5 | necochea
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | east london
# Processing Record 36 of Set 5 | adrar
# Processing Record 37 of Set 5 | knysna
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | dickinson
# Processing Record 40 of Set 5 | lianran
# Processing Record 41 of Set 5 | syracuse
# Processing Record 42 of Set 5 | tiksi
# Processing Record 43 of Set 5 | bima
# Processing Record 44 of Set 5 | vuktyl
# Processing Record 45 of Set 5 | berlevag
# Processing Record 46 of Set 5 | guangyuan
# Processing Record 47 of Set 5 | fairbanks
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | west wendover
# Processing Record 0 of Set 6 | grindavik
# Processing Record 1 of Set 6 | mehamn
# Processing Record 2 of Set 6 | anadyr
# Processing Record 3 of Set 6 | maymanak
# City not found. Skipping...
# Processing Record 4 of Set 6 | nanortalik
# Processing Record 5 of Set 6 | sucua
# Processing Record 6 of Set 6 | nome
# Processing Record 7 of Set 6 | labuhan
# Processing Record 8 of Set 6 | chernyshevskiy
# Processing Record 9 of Set 6 | chapais
# Processing Record 10 of Set 6 | umm kaddadah
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | mahebourg
# Processing Record 13 of Set 6 | boyolangu
# Processing Record 14 of Set 6 | ballangen
# Processing Record 15 of Set 6 | kachug
# Processing Record 16 of Set 6 | beringovskiy
# Processing Record 17 of Set 6 | uvinza
# Processing Record 18 of Set 6 | tobol
# Processing Record 19 of Set 6 | bria
# Processing Record 20 of Set 6 | iberia
# Processing Record 21 of Set 6 | kaili
# Processing Record 22 of Set 6 | san patricio
# Processing Record 23 of Set 6 | sarangani
# Processing Record 24 of Set 6 | jacareacanga
# Processing Record 25 of Set 6 | souflion
# City not found. Skipping...
# Processing Record 26 of Set 6 | opunake
# Processing Record 27 of Set 6 | santa maria
# Processing Record 28 of Set 6 | kieta
# Processing Record 29 of Set 6 | iskateley
# Processing Record 30 of Set 6 | okha
# Processing Record 31 of Set 6 | asfi
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | chateauroux
# Processing Record 34 of Set 6 | pachelma
# Processing Record 35 of Set 6 | lata
# Processing Record 36 of Set 6 | nhamunda
# Processing Record 37 of Set 6 | tyup
# Processing Record 38 of Set 6 | pemangkat
# Processing Record 39 of Set 6 | santiago del estero
# Processing Record 40 of Set 6 | santa lucia
# Processing Record 41 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 6 | eydhafushi
# Processing Record 43 of Set 6 | tocopilla
# Processing Record 44 of Set 6 | lamu
# Processing Record 45 of Set 6 | nuuk
# Processing Record 46 of Set 6 | aswan
# Processing Record 47 of Set 6 | taoudenni
# Processing Record 48 of Set 6 | cherskiy
# Processing Record 49 of Set 6 | arraias
# Processing Record 0 of Set 7 | guarapari
# Processing Record 1 of Set 7 | seoul
# Processing Record 2 of Set 7 | verkhoturye
# Processing Record 3 of Set 7 | salinas
# Processing Record 4 of Set 7 | carnarvon
# Processing Record 5 of Set 7 | saint anthony
# Processing Record 6 of Set 7 | la crosse
# Processing Record 7 of Set 7 | manacapuru
# Processing Record 8 of Set 7 | yenagoa
# Processing Record 9 of Set 7 | honningsvag
# Processing Record 10 of Set 7 | abagur
# Processing Record 11 of Set 7 | maple creek
# Processing Record 12 of Set 7 | crotone
# Processing Record 13 of Set 7 | chignautla
# Processing Record 14 of Set 7 | gerash
# Processing Record 15 of Set 7 | soe
# Processing Record 16 of Set 7 | igarka
# Processing Record 17 of Set 7 | davila
# Processing Record 18 of Set 7 | balad
# Processing Record 19 of Set 7 | takoradi
# Processing Record 20 of Set 7 | gisborne
# Processing Record 21 of Set 7 | markova
# Processing Record 22 of Set 7 | bow island
# Processing Record 23 of Set 7 | erzurum
# Processing Record 24 of Set 7 | sumenep
# Processing Record 25 of Set 7 | port macquarie
# Processing Record 26 of Set 7 | hofn
# Processing Record 27 of Set 7 | niamey
# Processing Record 28 of Set 7 | puxinana
# Processing Record 29 of Set 7 | sorland
# Processing Record 30 of Set 7 | lorengau
# Processing Record 31 of Set 7 | mandalgovi
# Processing Record 32 of Set 7 | haimen
# Processing Record 33 of Set 7 | fez
# Processing Record 34 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 7 | quatre cocos
# Processing Record 36 of Set 7 | manitouwadge
# Processing Record 37 of Set 7 | flinders
# Processing Record 38 of Set 7 | ha giang
# Processing Record 39 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 7 | santa cruz
# Processing Record 41 of Set 7 | caravelas
# Processing Record 42 of Set 7 | half moon bay
# Processing Record 43 of Set 7 | sao felix do xingu
# Processing Record 44 of Set 7 | comodoro rivadavia
# Processing Record 45 of Set 7 | vestmannaeyjar
# Processing Record 46 of Set 7 | lethem
# Processing Record 47 of Set 7 | sydney
# Processing Record 48 of Set 7 | tual
# Processing Record 49 of Set 7 | lodeynoye pole
# Processing Record 0 of Set 8 | yinchuan
# Processing Record 1 of Set 8 | nexo
# Processing Record 2 of Set 8 | rodrigues alves
# Processing Record 3 of Set 8 | ninghai
# Processing Record 4 of Set 8 | freeport
# Processing Record 5 of Set 8 | rocha
# Processing Record 6 of Set 8 | codrington
# Processing Record 7 of Set 8 | barnala
# Processing Record 8 of Set 8 | kouqian
# Processing Record 9 of Set 8 | westport
# Processing Record 10 of Set 8 | aksu
# Processing Record 11 of Set 8 | collie
# Processing Record 12 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 13 of Set 8 | toguchin
# Processing Record 14 of Set 8 | haysville
# Processing Record 15 of Set 8 | marsh harbour
# Processing Record 16 of Set 8 | vostok
# Processing Record 17 of Set 8 | gorontalo
# Processing Record 18 of Set 8 | saint-augustin
# Processing Record 19 of Set 8 | pasni
# Processing Record 20 of Set 8 | tataru
# Processing Record 21 of Set 8 | kismayo
# Processing Record 22 of Set 8 | russell
# Processing Record 23 of Set 8 | sulangan
# Processing Record 24 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 8 | diamantino
# Processing Record 26 of Set 8 | tuatapere
# Processing Record 27 of Set 8 | lingao
# Processing Record 28 of Set 8 | maceio
# Processing Record 29 of Set 8 | axim
# Processing Record 30 of Set 8 | kidal
# Processing Record 31 of Set 8 | birjand
# Processing Record 32 of Set 8 | tottori
# Processing Record 33 of Set 8 | te anau
# Processing Record 34 of Set 8 | derazhnya
# Processing Record 35 of Set 8 | khuzdar
# Processing Record 36 of Set 8 | neiafu
# Processing Record 37 of Set 8 | san quintin
# Processing Record 38 of Set 8 | cockburn town
# Processing Record 39 of Set 8 | jiayuguan
# Processing Record 40 of Set 8 | lalmohan
# Processing Record 41 of Set 8 | letlhakane
# Processing Record 42 of Set 8 | makaha
# Processing Record 43 of Set 8 | muroto
# Processing Record 44 of Set 8 | gravdal
# Processing Record 45 of Set 8 | aljezur
# Processing Record 46 of Set 8 | zhangye
# Processing Record 47 of Set 8 | innisfail
# Processing Record 48 of Set 8 | duncan
# Processing Record 49 of Set 8 | mezen
# Processing Record 0 of Set 9 | puerto carreno
# Processing Record 1 of Set 9 | najran
# Processing Record 2 of Set 9 | caluquembe
# Processing Record 3 of Set 9 | changping
# Processing Record 4 of Set 9 | balasheyka
# Processing Record 5 of Set 9 | pathein
# Processing Record 6 of Set 9 | pimentel
# Processing Record 7 of Set 9 | camacupa
# Processing Record 8 of Set 9 | neryungri
# Processing Record 9 of Set 9 | gat
# Processing Record 10 of Set 9 | naze
# Processing Record 11 of Set 9 | korla
# Processing Record 12 of Set 9 | regeneracao
# Processing Record 13 of Set 9 | rio grande
# Processing Record 14 of Set 9 | banda aceh
# Processing Record 15 of Set 9 | hasaki
# Processing Record 16 of Set 9 | chimbarongo
# Processing Record 17 of Set 9 | luderitz
# Processing Record 18 of Set 9 | rawson
# Processing Record 19 of Set 9 | deputatskiy
# Processing Record 20 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 9 | mandali
# Processing Record 22 of Set 9 | saulkrasti
# Processing Record 23 of Set 9 | la roche-sur-yon
# Processing Record 24 of Set 9 | mogadishu
# Processing Record 25 of Set 9 | yeppoon
# Processing Record 26 of Set 9 | cabrero
# Processing Record 27 of Set 9 | cooma
# Processing Record 28 of Set 9 | tuy hoa
# Processing Record 29 of Set 9 | ulladulla
# Processing Record 30 of Set 9 | nouadhibou
# Processing Record 31 of Set 9 | kahului
# Processing Record 32 of Set 9 | havre
# Processing Record 33 of Set 9 | vila franca do campo
# Processing Record 34 of Set 9 | murray bridge
# Processing Record 35 of Set 9 | capiibary
# Processing Record 36 of Set 9 | progreso
# Processing Record 37 of Set 9 | trincomalee
# Processing Record 38 of Set 9 | kurilsk
# Processing Record 39 of Set 9 | baruun-urt
# Processing Record 40 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 9 | melur
# Processing Record 42 of Set 9 | livingston
# Processing Record 43 of Set 9 | husavik
# Processing Record 44 of Set 9 | kutum
# Processing Record 45 of Set 9 | yar-sale
# Processing Record 46 of Set 9 | antalaha
# Processing Record 47 of Set 9 | ixtapa
# Processing Record 48 of Set 9 | sola
# Processing Record 49 of Set 9 | seddon
# Processing Record 0 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 10 | sambava
# Processing Record 2 of Set 10 | svetlaya
# Processing Record 3 of Set 10 | kenai
# Processing Record 4 of Set 10 | prenzlau
# Processing Record 5 of Set 10 | nantucket
# Processing Record 6 of Set 10 | kirakira
# Processing Record 7 of Set 10 | guerrero negro
# Processing Record 8 of Set 10 | alugan
# Processing Record 9 of Set 10 | kanniyakumari
# Processing Record 10 of Set 10 | mount gambier
# Processing Record 11 of Set 10 | san cristobal
# Processing Record 12 of Set 10 | aktash
# Processing Record 13 of Set 10 | sayyan
# Processing Record 14 of Set 10 | kashima
# Processing Record 15 of Set 10 | svetlogorsk
# Processing Record 16 of Set 10 | gaoual
# Processing Record 17 of Set 10 | prieska
# Processing Record 18 of Set 10 | tarko-sale
# Processing Record 19 of Set 10 | mporokoso
# Processing Record 20 of Set 10 | ust-kut
# Processing Record 21 of Set 10 | kenitra
# Processing Record 22 of Set 10 | alofi
# Processing Record 23 of Set 10 | alyangula
# Processing Record 24 of Set 10 | marawi
# Processing Record 25 of Set 10 | am timan
# Processing Record 26 of Set 10 | bermejo
# Processing Record 27 of Set 10 | ancud
# Processing Record 28 of Set 10 | lower burrell
# Processing Record 29 of Set 10 | shache
# Processing Record 30 of Set 10 | liwale
# Processing Record 31 of Set 10 | majene
# Processing Record 32 of Set 10 | loralai
# Processing Record 33 of Set 10 | gold coast
# Processing Record 34 of Set 10 | mount isa
# Processing Record 35 of Set 10 | klaksvik
# Processing Record 36 of Set 10 | fort beaufort
# Processing Record 37 of Set 10 | siniscola
# Processing Record 38 of Set 10 | acapulco
# Processing Record 39 of Set 10 | port shepstone
# Processing Record 40 of Set 10 | moranbah
# Processing Record 41 of Set 10 | kedzierzyn-kozle
# Processing Record 42 of Set 10 | durban
# Processing Record 43 of Set 10 | tilichiki
# Processing Record 44 of Set 10 | miandrivazo
# Processing Record 45 of Set 10 | bonavista
# Processing Record 46 of Set 10 | perbaungan
# Processing Record 47 of Set 10 | yanji
# Processing Record 48 of Set 10 | gaomi
# Processing Record 49 of Set 10 | aneza
# Processing Record 0 of Set 11 | ronneby
# Processing Record 1 of Set 11 | lavrentiya
# Processing Record 2 of Set 11 | bonthe
# Processing Record 3 of Set 11 | weligama
# Processing Record 4 of Set 11 | lake cowichan
# Processing Record 5 of Set 11 | domoni
# Processing Record 6 of Set 11 | vanimo
# Processing Record 7 of Set 11 | micheweni
# Processing Record 8 of Set 11 | sortland
# Processing Record 9 of Set 11 | tehachapi
# Processing Record 10 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 11 | juneau
# Processing Record 12 of Set 11 | makung
# City not found. Skipping...
# Processing Record 13 of Set 11 | kitob
# Processing Record 14 of Set 11 | yavaros
# Processing Record 15 of Set 11 | kamaishi
# Processing Record 16 of Set 11 | kungurtug
# Processing Record 17 of Set 11 | alberdi
# Processing Record 18 of Set 11 | gasa
# Processing Record 19 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 11 | atar
# Processing Record 21 of Set 11 | kyra
# Processing Record 22 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 23 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 11 | port-gentil
# Processing Record 25 of Set 11 | santa fe
# Processing Record 26 of Set 11 | simplicio mendes
# Processing Record 27 of Set 11 | carutapera
# Processing Record 28 of Set 11 | tura
# Processing Record 29 of Set 11 | maragogi
# Processing Record 30 of Set 11 | sena madureira
# Processing Record 31 of Set 11 | lompoc
# Processing Record 32 of Set 11 | polovinnoye
# Processing Record 33 of Set 11 | erenhot
# Processing Record 34 of Set 11 | rio bueno
# Processing Record 35 of Set 11 | umba
# Processing Record 36 of Set 11 | tromso
# Processing Record 37 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 11 | mbini
# Processing Record 39 of Set 11 | sioux lookout
# Processing Record 40 of Set 11 | hami
# Processing Record 41 of Set 11 | clearwater
# Processing Record 42 of Set 11 | grants
# Processing Record 43 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 11 | sao raimundo nonato
# Processing Record 46 of Set 11 | matara
# Processing Record 47 of Set 11 | kasama
# Processing Record 48 of Set 11 | araguacu
# Processing Record 49 of Set 11 | krasnokamensk
# Processing Record 0 of Set 12 | gazojak
# Processing Record 1 of Set 12 | broome
# Processing Record 2 of Set 12 | real
# Processing Record 3 of Set 12 | prince rupert
# Processing Record 4 of Set 12 | manzhouli
# Processing Record 5 of Set 12 | kaspiyskiy
# Processing Record 6 of Set 12 | nuevo ideal
# Processing Record 7 of Set 12 | morondava
# Processing Record 8 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 12 | burica
# City not found. Skipping...
# Processing Record 10 of Set 12 | topolobampo
# Processing Record 11 of Set 12 | kysyl-syr
# Processing Record 12 of Set 12 | po
# City not found. Skipping...
# Processing Record 13 of Set 12 | majdanpek
# Processing Record 14 of Set 12 | arman
# Processing Record 15 of Set 12 | bonfim
# Processing Record 16 of Set 12 | linxia
# Processing Record 17 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 18 of Set 12 | yashkul
# Processing Record 19 of Set 12 | rameswaram
# Processing Record 20 of Set 12 | rabo de peixe
# Processing Record 21 of Set 12 | meulaboh
# Processing Record 22 of Set 12 | mutis
# Processing Record 23 of Set 12 | tecoanapa
# Processing Record 24 of Set 12 | moramanga
# Processing Record 25 of Set 12 | vila do maio
# Processing Record 26 of Set 12 | wadi musa
# Processing Record 27 of Set 12 | fomboni
# Processing Record 28 of Set 12 | swan hill
# Processing Record 29 of Set 12 | shitanjing
# Processing Record 30 of Set 12 | nizhnevartovsk
# Processing Record 31 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 32 of Set 12 | jerecuaro
# Processing Record 33 of Set 12 | atambua
# Processing Record 34 of Set 12 | asau
# Processing Record 35 of Set 12 | ariquemes
# Processing Record 36 of Set 12 | tukrah
# Processing Record 37 of Set 12 | paradise
# Processing Record 38 of Set 12 | reforma
# Processing Record 39 of Set 12 | tkvarcheli
# City not found. Skipping...
# Processing Record 40 of Set 12 | vesele
# Processing Record 41 of Set 12 | muli
# Processing Record 42 of Set 12 | raudeberg
# Processing Record 43 of Set 12 | labrea
# Processing Record 44 of Set 12 | calatayud
# Processing Record 45 of Set 12 | faanui
# Processing Record 46 of Set 12 | belmonte
# Processing Record 47 of Set 12 | kasongo
# Processing Record 48 of Set 12 | cap-haitien
# Processing Record 49 of Set 12 | touros
# Processing Record 0 of Set 13 | dingle
# Processing Record 1 of Set 13 | cartagena del chaira
# Processing Record 2 of Set 13 | polunochnoye
# Processing Record 3 of Set 13 | nalvo
# Processing Record 4 of Set 13 | muros
# Processing Record 5 of Set 13 | dillon
# Processing Record 6 of Set 13 | atengo
# Processing Record 7 of Set 13 | kwinana
# Processing Record 8 of Set 13 | constantine
# Processing Record 9 of Set 13 | ketchikan
# Processing Record 10 of Set 13 | plettenberg bay
# Processing Record 11 of Set 13 | pionerskiy
# Processing Record 12 of Set 13 | at-bashi
# Processing Record 13 of Set 13 | huarmey
# Processing Record 14 of Set 13 | luwingu
# Processing Record 15 of Set 13 | ilhabela
# Processing Record 16 of Set 13 | zhatay
# Processing Record 17 of Set 13 | bahia blanca
# Processing Record 18 of Set 13 | ningan
# City not found. Skipping...
# Processing Record 19 of Set 13 | terrace
# Processing Record 20 of Set 13 | muhos
# Processing Record 21 of Set 13 | nizwa
# Processing Record 22 of Set 13 | bonito
# Processing Record 23 of Set 13 | arucas
# Processing Record 24 of Set 13 | albion
# Processing Record 25 of Set 13 | catuday
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)
city_data_pd.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  nikolskoye  59.70   30.79     33.80        80          90        8.95
# 1   upernavik  72.79  -56.15     18.86        89         100       16.24
# 2        nago  26.59  127.98     82.40        61          75       16.11
# 3        palu  -0.89  119.87     87.82        63          63        2.89
# 4      castro -24.79  -50.01     62.08        96          94        2.98
#
#   Country        Date
# 0      RU  1605497645
# 1      GL  1605497646
# 2      JP  1605497646
# 3      ID  1605497646
# 4      BR  1605497646

# %%
city_data_pd.to_csv("city_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  582.000000  582.000000  582.000000  582.000000  582.000000  582.000000
# mean    19.169313   19.468557   56.775378   73.781787   52.060137    8.201804
# std     33.308811   90.052915   24.185105   19.302523   39.597651    6.054134
# min    -54.800000 -175.200000  -21.350000   17.000000    0.000000    0.090000
# 25%     -8.717500  -60.452500   40.012500   62.000000    5.250000    3.360000
# 50%     22.860000   25.765000   62.520000   79.000000   57.000000    6.930000
# 75%     46.657500   99.995000   75.990000   89.000000   92.000000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   32.570000
#
#                Date
# count  5.820000e+02
# mean   1.605498e+09
# std    7.357125e+01
# min    1.605497e+09
# 25%    1.605498e+09
# 50%    1.605498e+09
# 75%    1.605498e+09
# max    1.605498e+09

# %%
#  Get the indices of cities that have humidity over 100%.

dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
                                  
dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  nikolskoye  59.70   30.79     33.80        80          90        8.95
# 1   upernavik  72.79  -56.15     18.86        89         100       16.24
# 2        nago  26.59  127.98     82.40        61          75       16.11
# 3        palu  -0.89  119.87     87.82        63          63        2.89
# 4      castro -24.79  -50.01     62.08        96          94        2.98
#
#   Country        Date
# 0      RU  1605497645
# 1      GL  1605497646
# 2      JP  1605497646
# 3      ID  1605497646
# 4      BR  1605497646

# %%
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1temp.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build scatter plot for latitude vs. humidity 
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2hum.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build scatter plot for latitude vs. cloudiness 
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3cloud.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind_speed 
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("wind_speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4windsp.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()
    
    # Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.7260530203162252

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(-50, 20))
# Out:
# The r-value is: 0.23770662713539284

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(6,30))
# Out:
# The r-value is: 0.10143124397219429

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(-50, 20))
# Out:
# The r-value is: 0.07130972550902026

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(6,30))
# Out:
# The r-value is: 0.0843391383742882

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness',(-50, 20))
# Out:
# The r-value is: 0.15216378404222988

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(6,30))
# Out:
# The r-value is: 0.0636171314694731

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed',(-50, 20))
# Out:
# The r-value is: 0.11785777570493039
